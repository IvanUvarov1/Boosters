# %% [markdown]
# Тетрадка предназначена для студентов образвательного проекта Booster MDS использование вне проекта запрещено.

# %% [markdown]
# ##### Задания не несут смысловой нагрузки для реальной жизни, они сделаны лишь для того, чтоб научить использовать Pandas

# %% [markdown]
# #### Каждое задание оценивает в 1 балл, для успешной сдачи задания нужно набрать 12 баллов

# %% [markdown]
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. In particular, the Cleveland database is the only one that has been used by ML researchers to this date. The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 1.

# %% [markdown]
# https://www.kaggle.com/ronitf/heart-disease-uci

# %% [markdown]
# ___

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('heart_pandas.csv')

# %%
data.head(5)
# Out:
#    age     sex   chest_pain_type  resting_blood_pressure  cholesterol  \
# 0   63    male  non-anginal pain                     145          233
# 1   37    male   atypical angina                     130          250
# 2   41  female    typical angina                     130          204
# 3   56    male    typical angina                     120          236
# 4   57  female    typical angina                     120          354
#
#      fasting_blood_sugar               rest_ecg  max_heart_rate_achieved  \
# 0  greater than 120mg/ml                 normal                      150
# 1    lower than 120mg/ml  ST-T wave abnormality                      187
# 2    lower than 120mg/ml                 normal                      172
# 3    lower than 120mg/ml  ST-T wave abnormality                      178
# 4    lower than 120mg/ml  ST-T wave abnormality                      163
#
#   exercise_induced_angina  st_depression   st_slope  num_major_vessels  \
# ...

# %% [markdown]
# #### Описание признаков

# %% [markdown]
# **age**: The person's age in years
#
# **sex**: The person's sex (1 = male, 0 = female)
#
# **cp**: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# **trestbps**: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# **chol**: The person's cholesterol measurement in mg/dl
#
# **fbs**: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# **restecg**: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# **thalach**: The person's maximum heart rate achieved
#
# **exang**: Exercise induced angina (1 = yes; 0 = no)
#
# **oldpeak**: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot. See more here)
#
# **slope**: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# **ca**: The number of major vessels (0-3)
#
# **thal**: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# **target**: Heart disease (0 = no, 1 = yes)

# %% [markdown]
# > 1. age
# > 2. sex
# > 3. chest pain type (4 values)
# > 4. resting blood pressure
# > 5. serum cholestoral in mg/dl
# > 6. fasting blood sugar > 120 mg/dl
# > 7. resting electrocardiographic results (values 0,1,2)
# > 8. maximum heart rate achieved
# > 9. exercise induced angina
# > 10. oldpeak = ST depression induced by exercise relative to rest
# > 11. the slope of the peak exercise ST segment
# > 12. number of major vessels (0-3) colored by flourosopy
# > 13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# ___

# %% [markdown]
# **Сколько мужчин в датасете? Сколько женщен? (sex) **

# %%
print(len(data[data['sex'] == 'male']))
print(len(data[data['sex'] == 'female']))
# Out:
# 207
# 96

# %%
207
96

# %% [markdown]
#  **Какой процент мужчин в датасете? (решите в одну строчку, не используя предыдущий результат. Не забудте знак процента) **

# %%
len(data[data['sex'] == 'male'] ) / len(data) * 100
# Out:
# 68.31683168316832

# %%
68.31683168316832

# %% [markdown]
# **Сколько мужчин имеют заболевание сердца? Сколько женщин имеют заболевание сердца? **

# %%
print(len(data[(data['sex'] == 'male') & (data['target'] == 1)]))
print(len(data[(data['sex'] == 'female') & (data['target'] == 1)]))
# Out:
# 93
# 72

# %%
93
72

# %% [markdown]
# **Какую долю, от общего числа пациентов, занимают мужчины не имеющие болезнь сердца?**

# %%
len(data[(data['sex'] == 'male') & (data['target'] == 0)])/len(data)
# Out:
# 0.37623762376237624

# %%
0.37623762376237624

# %% [markdown]
# **Сколько лет самому молодому пациенту, страдающему болезнью сердца?**

# %%
data[(data['target'] == 1)].sort_values('age')
# Out:
#      age     sex   chest_pain_type  resting_blood_pressure  cholesterol  \
# 72    29    male    typical angina                     130          204
# 58    34    male  non-anginal pain                     118          182
# 125   34  female    typical angina                     118          210
# 157   35    male    typical angina                     122          192
# 65    35  female    typical angina                     138          183
# 115   37  female   atypical angina                     120          215
# 1     37    male   atypical angina                     130          250
# 163   38    male   atypical angina                     138          175
# 164   38    male   atypical angina                     138          175
# 44    39    male   atypical angina                     140          321
# 154   39  female   atypical angina                     138          220
# 124   39  female   atypical angina                      94          199
# ...

# %%
29

# %% [markdown]
# **Сколько лет самому возастному пациенту, у которого нет проблем с сердцем?**

# %%
data[(data['target'] == 0)].sort_values('age', ascending = False)
# Out:
#      age     sex   chest_pain_type  resting_blood_pressure  cholesterol  \
# 238   77    male    typical angina                     125          304
# 234   70    male    typical angina                     130          322
# 240   70    male   atypical angina                     160          269
# 225   70    male    typical angina                     145          174
# 249   69    male   atypical angina                     140          254
# 300   68    male    typical angina                     144          193
# 203   68    male   atypical angina                     180          274
# 197   67    male    typical angina                     125          254
# 293   67    male   atypical angina                     152          212
# 272   67    male    typical angina                     120          237
# 253   67    male    typical angina                     100          299
# 166   67    male    typical angina                     120          229
# ...

# %%
77

# %% [markdown]
# **Сколько лет самой молодой женщине, которая страдает болезнью сердца?**

# %%
data[(data['sex'] == 'female') & (data['target'] == 1)].sort_values('age')
# Out:
#      age     sex   chest_pain_type  resting_blood_pressure  cholesterol  \
# 125   34  female    typical angina                     118          210
# 65    35  female    typical angina                     138          183
# 115   37  female   atypical angina                     120          215
# 154   39  female   atypical angina                     138          220
# 124   39  female   atypical angina                      94          199
# 2     41  female    typical angina                     130          204
# 134   41  female    typical angina                     126          306
# 122   41  female   atypical angina                     112          268
# 30    41  female    typical angina                     105          198
# 84    42  female    typical angina                     102          265
# 142   42  female   atypical angina                     120          209
# 74    43  female   atypical angina                     122          213
# ...

# %%
34

# %% [markdown]
# **Какой средний возраст женщин?**

# %%
data[(data['sex'] == 'female')].mean()['age']
# Out:
# 55.677083333333336

# %%
55.677083333333336

# %% [markdown]
# **Каковы средние значения и среднеквадратичные отклонения возраста тех, кто страдают болезнью сердца?**

# %%
print(data[data['target'] == 1].mean()['age'])
print(data[data['target'] == 1].std()['age'])
# Out:
# 52.4969696969697
# 9.550650751946778

# %%
52.4969696969697
9.550650751946778

# %% [markdown]
# ** Правда ли, что люди не болеющие болезнью сердца имеют уровня холестерина меньше среднего? (chol) **

# %%
cholesterol_not_disease = data[data['target'] == 0].mean()['cholesterol']
cholesterol_average = data.mean()['cholesterol']
cholesterol_not_disease < cholesterol_average
# Out:
# False

# %%
Неправда

# %% [markdown]
# **Выведите статистику rest_ecg для все числовых признаков, его максимально и среднее значение (используйте groupby(), решите в одну строчку)**

# %%
data.groupby('rest_ecg').agg(['max','mean'])
# Out:
#                              age            resting_blood_pressure  \
#                              max       mean                    max
# rest_ecg
# ST-T wave abnormality         71  52.914474                    180
# left ventricular hypertrophy  76  61.000000                    180
# normal                        77  55.687075                    200
#
#                                          cholesterol              \
#                                     mean         max        mean
# rest_ecg
# ST-T wave abnormality         129.065789         354  237.269737
# left ventricular hypertrophy  140.500000         327  261.750000
# normal                        134.027211         564  255.142857
#
#                              max_heart_rate_achieved              \
#                                                  max        mean
# rest_ecg
# ST-T wave abnormality                            194  151.960526
# left ventricular hypertrophy                     140  125.750000
# ...

# %%
## Ваш ответ:

# %% [markdown]
# **Посчитайте у кого уровень депрессии при физический нагрузке выше (в среднем), среди мужчин страдающих болезнью сердца или среди женщин не страдающих болезнью сердца (st_depression)**

# %%
male_depression = data[(data['sex'] == 'male') & (data['target'] == 1)]['st_depression'].mean()
female_depression = data[(data['sex'] == 'female') & (data['target'] == 0)]['st_depression'].mean()
if male_depression>female_depression:
    print('У мужчин')
else: print('У женщин')
# Out:
# У женщин

# %%
У женщин

# %% [markdown]
# **Посчтитайте максимальный и минимальный уровень холестерина для каждого типа chest_pain_type, rest_ecg, thalassemia. Пишите код оптимально, можно использовать циклы**

# %%
data.groupby('chest_pain_type').agg([max,min])['cholesterol']
# Out:
#                   max  min
# chest_pain_type
# atypical angina   564  126
# non-anginal pain  298  182
# typical angina    409  131

# %%
data.groupby('rest_ecg').agg([max,min])['cholesterol']
# Out:
#                               max  min
# rest_ecg
# ST-T wave abnormality         354  126
# left ventricular hypertrophy  327  197
# normal                        564  149

# %%
data.groupby('thalassemia').agg([max,min])['cholesterol']
# Out:
#                    max  min
# thalassemia
# fixed defect       417  141
# normal             318  169
# reversable defect  564  126

# %%
## Ваш ответ:

# %% [markdown]
# **Сколько значений может принимать каждый из категориальных признаков?**

# %%
columns = ['sex', 'chest_pain_type','fasting_blood_sugar','rest_ecg','exercise_induced_angina','st_slope','thalassemia','target']
for i in columns:
    print(i + ' : ' +str(len(data[i].unique())))
# Out:
# sex : 2
# chest_pain_type : 3
# fasting_blood_sugar : 2
# rest_ecg : 3
# exercise_induced_angina : 2
# st_slope : 2
# thalassemia : 3
# target : 2

# %%
sex : 2
chest_pain_type : 3
fasting_blood_sugar : 2
rest_ecg : 3
exercise_induced_angina : 2
st_slope : 2
thalassemia : 3
target : 2

# %% [markdown]
# **У какого категориального признака наблюдается самый сильный дизбаланс классов?**

# %%
columns = ['sex', 'chest_pain_type','fasting_blood_sugar','rest_ecg','exercise_induced_angina','st_slope','thalassemia','target']
#я хз, можно ли на автомате искать категориальные признаки, не придумал способа, кроме как вручную забить
d = {}
length = []
kolvo_klassov = 0
spisok_znacheniy = []
disbalance = []

for i in columns:
    length.append(len(data[i].unique())) #складываем в список количество классов из каждого признака
    for j in range(len(data[i])): # формируем количество попаданий в каждый класс по каждому признаку
        if data[i][j] in d.keys():
            d[data[i][j]] += 1
        else: d[data[i][j]] = 1
    for key in d.keys():
        spisok_znacheniy.append(d[key]) # переносим количество попаданий в отдельный список и зануляем словарь. Было 
            d = {} #сделано из за того, что есть классы с одинаковыми именами, а в словаре не могут быть ключи с одинаковыми именами
    
for i in range(len(length)):
    kolvo_klassov = length[i] #количество классов для каждого признака
    for j in range(length[i]):
        test_spisok.append(spisok_znacheniy[j])#длина этого списка будет сравниваться с количеством классов
        if len(test_spisok) == kolvo_klassov:#после того, длина списка оказывается равна количеству классов
            del spisok_znacheniy[:kolvo_klassov]#мы удаляем из списка со всеми значениями уже пройденные значения
            print('Дисбаланс ' + str(i+1) + ' класса - ' + str(max(test_spisok) - min(test_spisok)))#а в тестовом смотрим разницу между min и max
            disbalance.append(max(test_spisok) - min(test_spisok))
            break
    test_spisok = []#обнуляем тестовый список, чтобы минимумы и максимумы предыдущих классов нам не мешали

print(str(columns[disbalance.index(max(disbalance))]) + ' имеет самый большой дисбаланс - ' + str(max(disbalance)))
# Out:
# Дисбаланс 1 класса - 111
# Дисбаланс 2 класса - 170
# Дисбаланс 3 класса - 213
# Дисбаланс 4 класса - 148
# Дисбаланс 5 класса - 105
# Дисбаланс 6 класса - 19
# Дисбаланс 7 класса - 146
# Дисбаланс 8 класса - 27
# fasting_blood_sugar имеет самый большой дисбаланс - 213

# %%
fasting_blood_sugar

# %% [markdown]
# ---

# %% [markdown]
# @Booster
# Мамкин Data Scientist
#
# tg @mommyscience
